# %%
# import rasterio
import numpy as np

# file_path = r"D:\TP_DELEDETECTION_ADV\5418_DEMBELE_Bassala\arcgispro\examen\sentinelle\Raster/classification_sentinelle2.tif"


# # Charger le fichier GeoTIFF d'occupation du sol exporté depuis ArcGIS
# with rasterio.open(file_path) as src:
#     labels = src.read(1)  # Lire la première bande, qui contient les classes d'occupation

# # Vérifier la taille et les classes uniques
# print(labels.shape)  # Par exemple, (512, 512)
# print(np.unique(labels))  # Affiche les classes présentes dans l'image classifiée

# # Sauvegarder en format .npy
# np.save("labels.npy", labels)

# %%
import matplotlib.pyplot as plt

plt.imshow(labels, cmap='tab10')  # Par exemple, pour 10 classes
plt.colorbar( )
plt.title("Classification d'Occupation du Sol")
plt.show()

# %%
labels = np.load('labels.npy')
